# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

spark.conf.set('spark.sql.repl.eagerEval.enabled', True)

# %%
import pandas as pd

data_df = pd.read_csv('data/customer-orders.csv')
df = spark.createDataFrame(data_df)
df
# Out:
# DataFrame[CustomerID: bigint, ItemID: bigint, Amount: double]

# %%
data_df
# Out:
#       CustomerID  ItemID  Amount
# 0             44    8602   37.19
# 1             35    5368   65.89
# 2              2    3391   40.64
# 3             47    6694   14.98
# 4             29     680   13.08
# ...          ...     ...     ...
# 9995          61     229   86.69
# 9996          50    4331   92.79
# 9997           2    9155   56.05
# 9998          23    2477   14.89
# 9999          97    5707   54.90
#
# [10000 rows x 3 columns]

# %%
df.show()
# Out:
# +----------+------+------+
# |CustomerID|ItemID|Amount|
# +----------+------+------+
# |        44|  8602| 37.19|
# |        35|  5368| 65.89|
# |         2|  3391| 40.64|
# |        47|  6694| 14.98|
# |        29|   680| 13.08|
# |        91|  8900| 24.59|
# |        70|  3959| 68.68|
# |        85|  1733| 28.53|
# |        53|  9900| 83.55|
# |        14|  1505|  4.32|
# |        51|  3378|  19.8|
# |        42|  6926| 57.77|
# |         2|  4424| 55.77|
# |        79|  9291| 33.17|
# |        50|  3901| 23.57|
# |        20|  6633|  6.49|
# |        15|  6148| 65.53|
# |        44|  8331| 99.19|
# |         5|  3505| 64.18|
# |        48|  5539| 32.42|
# +----------+------+------+
# only showing top 20 rows

# %%
df
# Out:
# DataFrame[CustomerID: bigint, ItemID: bigint, Amount: double]

# %%
# Write PySpark script to map each line to key/value pairs of customer ID and the amount.
customer_id_amount = df.rdd.map(lambda x: (x[0], x[2]))
df2 = customer_id_amount.toDF(["CustomerId","Amount"])

# %%
df2.show()
# Out:
# +----------+------+
# |CustomerId|Amount|
# +----------+------+
# |        44| 37.19|
# |        35| 65.89|
# |         2| 40.64|
# |        47| 14.98|
# |        29| 13.08|
# |        91| 24.59|
# |        70| 68.68|
# |        85| 28.53|
# |        53| 83.55|
# |        14|  4.32|
# |        51|  19.8|
# |        42| 57.77|
# |         2| 55.77|
# |        79| 33.17|
# |        50| 23.57|
# |        20|  6.49|
# |        15| 65.53|
# |        44| 99.19|
# |         5| 64.18|
# |        48| 32.42|
# +----------+------+
# only showing top 20 rows

# %%
# PySpark script to reduceByKey to add up amount spent by customer ID.
reduced = customer_id_amount.reduceByKey(lambda x, y: x + y)
for elment in reduced.collect():
    print(elment)
# Out:
# [Stage 9:>                                                          (0 + 8) / 8]
# (48, 4384.33)
# (0, 5524.950000000001)
# (88, 4830.55)
# (40, 5186.429999999999)
# (64, 5288.6900000000005)
# (72, 5337.44)
# (8, 5517.24)
# (80, 4727.860000000001)
# (16, 4979.06)
# (56, 4701.0199999999995)
# (24, 5259.919999999999)
# (96, 3924.2300000000005)
# (32, 5496.05)
# (57, 4628.4)
# (25, 5057.610000000001)
# (97, 5977.1900000000005)
# (1, 4958.599999999999)
# (73, 6206.2)
# (49, 4394.6)
# (65, 5140.349999999999)
# (9, 5322.650000000001)
# (41, 5637.620000000001)
# (17, 5032.679999999999)
# (33, 5254.66)
# (81, 5112.71)
# (89, 4851.4800000000005)
# (2, 5994.589999999999)
# (42, 5696.84)
# (50, 4517.27)
# (98, 4297.26)
# (26, 5250.4)
# (82, 4812.489999999999)
# (34, 5330.8)
# (18, 4921.2699999999995)
# (74, 4647.130000000001)
# (90, 5290.410000000001)
# (10, 4819.7)
# (58, 5437.73)
# (66, 4681.92)
# (35, 5155.42)
# (91, 4642.26)
# (51, 4975.22)
# (27, 4915.89)
# (83, 4635.8)
# (75, 4178.500000000001)
# (99, 4172.29)
# (19, 5059.43)
# (59, 5642.889999999999)
# (11, 5152.290000000001)
# (43, 5368.83)
# (3, 4659.63)
# (67, 4505.79)
# (44, 4756.889999999999)
# (20, 4836.860000000001)
# (4, 4815.05)
# (36, 4278.05)
# (12, 4664.59)
# (60, 5040.710000000001)
# (68, 6375.449999999999)
# (92, 5379.28)
# (76, 4904.21)
# (52, 5245.0599999999995)
# (84, 4652.94)
# (28, 5000.709999999999)
# (29, 5032.53)
# (85, 5503.43)
# (53, 4945.299999999999)
# (5, 4561.070000000001)
# (13, 4367.62)
# (61, 5497.479999999999)
# (21, 4707.41)
# (69, 5123.01)
# (37, 4735.2)
# (77, 4327.73)
# (93, 5265.75)
# (45, 3309.38)
# (70, 5368.25)
# (14, 4735.03)
# (22, 5019.450000000001)
# (54, 6065.390000000001)
# (86, 4908.8099999999995)
# (78, 4524.51)
# (6, 5397.88)
# (46, 5963.110000000001)
# (30, 4990.72)
# (62, 5253.320000000001)
# (94, 4475.57)
# (38, 4898.46)
# (47, 4316.3)
# (79, 3790.57)
# (15, 5413.51)
# (31, 4765.05)
# (55, 5298.09)
# (95, 4876.840000000001)
# (71, 5995.660000000001)
# (39, 6193.11)
# (7, 4755.070000000001)
# (23, 4042.65)
# (87, 5206.400000000001)
# (63, 5415.15)

# %%
# PySpark script to finally collect the result and display them on the spark shell.
results = reduced.collect()
results
# Out:
# [(48, 4384.33),
#  (0, 5524.950000000001),
#  (88, 4830.55),
#  (40, 5186.429999999999),
#  (64, 5288.6900000000005),
#  (72, 5337.44),
#  (8, 5517.24),
#  (80, 4727.860000000001),
#  (16, 4979.06),
#  (56, 4701.0199999999995),
#  (24, 5259.919999999999),
#  (96, 3924.2300000000005),
#  (32, 5496.05),
#  (57, 4628.4),
#  (25, 5057.610000000001),
#  (97, 5977.1900000000005),
#  (1, 4958.599999999999),
#  (73, 6206.2),
#  (49, 4394.6),
#  (65, 5140.349999999999),
#  (9, 5322.650000000001),
#  (41, 5637.620000000001),
#  (17, 5032.679999999999),
#  (33, 5254.66),
#  (81, 5112.71),
#  (89, 4851.4800000000005),
#  (2, 5994.589999999999),
#  (42, 5696.84),
#  (50, 4517.27),
#  (98, 4297.26),
#  (26, 5250.4),
#  (82, 4812.489999999999),
#  (34, 5330.8),
#  (18, 4921.2699999999995),
#  (74, 4647.130000000001),
#  (90, 5290.410000000001),
#  (10, 4819.7),
#  (58, 5437.73),
#  (66, 4681.92),
#  (35, 5155.42),
#  (91, 4642.26),
#  (51, 4975.22),
#  (27, 4915.89),
#  (83, 4635.8),
#  (75, 4178.500000000001),
#  (99, 4172.29),
#  (19, 5059.43),
#  (59, 5642.889999999999),
#  (11, 5152.290000000001),
#  (43, 5368.83),
#  (3, 4659.63),
#  (67, 4505.79),
#  (44, 4756.889999999999),
#  (20, 4836.860000000001),
#  (4, 4815.05),
#  (36, 4278.05),
#  (12, 4664.59),
#  (60, 5040.710000000001),
#  (68, 6375.449999999999),
#  (92, 5379.28),
#  (76, 4904.21),
#  (52, 5245.0599999999995),
#  (84, 4652.94),
#  (28, 5000.709999999999),
#  (29, 5032.53),
#  (85, 5503.43),
#  (53, 4945.299999999999),
#  (5, 4561.070000000001),
#  (13, 4367.62),
#  (61, 5497.479999999999),
#  (21, 4707.41),
#  (69, 5123.01),
#  (37, 4735.2),
#  (77, 4327.73),
#  (93, 5265.75),
#  (45, 3309.38),
#  (70, 5368.25),
#  (14, 4735.03),
#  (22, 5019.450000000001),
#  (54, 6065.390000000001),
#  (86, 4908.8099999999995),
#  (78, 4524.51),
#  (6, 5397.88),
#  (46, 5963.110000000001),
#  (30, 4990.72),
#  (62, 5253.320000000001),
#  (94, 4475.57),
#  (38, 4898.46),
#  (47, 4316.3),
#  (79, 3790.57),
#  (15, 5413.51),
#  (31, 4765.05),
#  (55, 5298.09),
#  (95, 4876.840000000001),
#  (71, 5995.660000000001),
#  (39, 6193.11),
#  (7, 4755.070000000001),
#  (23, 4042.65),
#  (87, 5206.400000000001),
#  (63, 5415.15)]
